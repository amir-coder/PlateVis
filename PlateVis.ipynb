# %% [markdown]
# <a href="https://colab.research.google.com/github/amir-coder/PlateVis/blob/amir%2Flab/PlateVis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook for debugging the CV model for the Plate Number recognition task
#
# **Please be carful not to commit your changes to the main branch**
#
# We suggest using this article as a refrence:
# https://pyimagesearch.com/2020/09/21/opencv-automatic-license-number-plate-recognition-anpr-with-python/

# %% [markdown]
# # Set up workspace

# %% [markdown]
# ### Cloning dataset repo

# %%
# !git clone https://github.com/mouadb0101/License_Plates_of_Algeria_Dataset.git
# Out:
# Cloning into 'License_Plates_of_Algeria_Dataset'...
# remote: Enumerating objects: 6853, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 6853 (delta 11), reused 0 (delta 0), pack-reused 6823
# Receiving objects: 100% (6853/6853), 237.01 MiB | 24.86 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (6908/6908), done.

# %% [markdown]
# ### installing dependencies

# %%
import os
HOME = os.getcwd()
DATASET = f'./License_Plates_of_Algeria_Dataset'
print(HOME)
# Out:
# /content

# %% [markdown]
# ### YOLO

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.7/78.2 GB disk)

# %% [markdown]
# ### Basic imports

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## Testing the inference result with pretrained COCO-model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.50 source={DATASET}/Detector/images/011/43264717_2092342271082201_2414204093493936128_n.jpg save=True
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.50 source={DATASET}/Detector/images/011/43299267_2092342044415557_2470261469770416128_n.jpg save=True
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.50 source={DATASET}/Detector/images/003/0.jpg save=True
# Out:
# /content
# 2023-12-20 09:32:04.238101: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-20 09:32:04.238167: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-20 09:32:04.239627: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-20 09:32:05.332794: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %%
# %cd {HOME}
Image(filename='runs/detect/predict2/43264717_2092342271082201_2414204093493936128_n.jpg', height=600)
# Out:
# /content

# %%
Image(filename='runs/detect/predict/43299267_2092342044415557_2470261469770416128_n.jpg', height=600)

# %%
Image(filename='runs/detect/predict6/0.jpg', height=600)

# %% [markdown]
# We notice that the basic COCO model detects the cars but not the license plats
